# %% [markdown]
# <h1> OpenCV </h1>
#
# Topics
# 1. Import the OpenCV model in Python
# 2. Load Images
# 3. Displaying the Images
# 4. Saving images
# 5. Displaying Image Dimensions

# %% [markdown]
# <h3>
# Import the OpenCV model in Python
# </h3>

# %%
import cv2

# %%
print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.11.0

# %% [markdown]
# <h3> Load Images </h3>

# %%
image = cv2.imread('images.png')

# %% [markdown]
# <h3> Displaying the Images </h3>

# %%
from matplotlib import pyplot as plt

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# images look simpler and easier
def imshow(title=" ", image=None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
imshow("Displaying Our First Image", image)

# %% [markdown]
# <h3> Saving images

# %%
cv2.imwrite('Output.png',image)
# Out:
# True

# %% [markdown]
# <h3> Displaying Image Dimensions

# %%
import numpy as np
print(image.shape)
# Out:
# (1002, 1215, 3)

# %%
image.shape[0]
# Out:
# 1002

# %% [markdown]
# See the first dimension is length.
# second is the width.
# third is the channel.

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 1002 pixels
# Width of Image: 1215 pixels
# Depth of Image: 3 colors components
